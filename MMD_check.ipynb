# %%
import pandas as pd
import pickle
from sklearn.datasets import load_svmlight_file

# %%
data = load_svmlight_file('data/usps')
X, y = data
temp = X.toarray()
# for i in range(784):
#     print(X[0, i])
img1 = temp[0, :].reshape(16, 16)
print(type(img1))
import matplotlib.pyplot as plt
plt.imshow(img1)
plt.show()
import numpy as np

print(np.where(y == 10)[0])
# Out:
# <class 'numpy.ndarray'>
# [  64   86   88   93  107  115  120  123  131  136  160  164  186  244
#   247  275  285  290  296  302  331  338  341  343  346  371  378  401
#   410  434  452  480  494  499  509  514  519  532  533  535  545  568
#   581  652  685  726  729  746  750  768  781  791  814  818  828  836
#   841  847  858  884  889  894  900  935  953  973  990  995 1000 1005
#  1007 1013 1024 1045 1053 1066 1095 1098 1102 1103 1107 1112 1115 1120
#  1148 1152 1166 1170 1174 1190 1213 1236 1256 1318 1336 1337 1341 1346
#  1351 1354 1358 1363 1440 1454 1456 1457 1459 1460 1464 1469 1477 1482
#  1558 1615 1620 1628 1633 1638 1642 1647 1651 1656 1660 1664 1666 1670
#  1673 1687 1696 1701 1703 1705 1707 1708 1723 1783 1791 1813 1817 1821
#  1843 1846 1854 1859 1863 1864 1869 1880 1885 1893 1901 1904 1913 1918
#  1923 1928 1933 1938 1943 1948 1953 1958 1963 1968 1973 1984 1992 1997
#  2002 2007 2011 2057 2090 2097 2102 2106 2107 2113 2115 2118 2122 2124
# ...

# %%
for item in y:
    print(item)
# Out:
# 7.0
# 6.0
# 5.0
# 8.0
# 4.0
# 7.0
# 4.0
# 2.0
# 1.0
# 2.0
# 8.0
# 1.0
# 2.0
# 2.0
# 8.0
# 8.0
# 5.0
# 9.0
# 1.0
# 2.0
# 5.0
# 9.0
# 8.0
# 5.0
# 9.0
# 8.0
# 4.0
# 8.0
# 5.0
# 2.0
# 4.0
# 7.0
# 8.0
# 5.0
# 2.0
# 4.0
# 8.0
# 8.0
# 5.0
# 6.0
# 5.0
# 3.0
# 8.0
# 5.0
# 2.0
# 4.0
# 8.0
# 8.0
# 5.0
# 1.0
# 7.0
# 4.0
# 3.0
# 1.0
# 9.0
# 7.0
# 7.0
# 3.0
# 1.0
# 9.0
# 8.0
# 9.0
# 3.0
# 1.0
# 10.0
# 1.0
# 3.0
# 3.0
# 1.0
# 9.0
# 2.0
# 3.0
# 1.0
# 9.0
# 4.0
# 4.0
# 3.0
# 9.0
# 3.0
# 3.0
# 1.0
# 9.0
# 2.0
# 5.0
# 5.0
# 9.0
# 10.0
# 9.0
# 10.0
# 7.0
# 8.0
# 7.0
# 2.0
# 10.0
# 8.0
# 1.0
# 9.0
# 1.0
# 5.0
# 7.0
# 9.0
# 1.0
# 1.0
# 4.0
# 1.0
# 9.0
# 1.0
# 10.0
# 1.0
# 4.0
# 9.0
# 1.0
# 2.0
# 3.0
# 3.0
# 10.0
# 1.0
# 7.0
# 7.0
# 6.0
# 10.0
# 3.0
# 1.0
# 10.0
# 2.0
# 5.0
# 2.0
# 3.0
# 8.0
# 2.0
# 1.0
# 10.0
# 1.0
# 9.0
# 1.0
# 8.0
# 10.0
# 2.0
# 4.0
# 1.0
# 5.0
# 5.0
# 4.0
# 6.0
# 2.0
# 7.0
# 9.0
# 6.0
# 5.0
# 5.0
# 7.0
# 9.0
# 5.0
# 5.0
# 9.0
# 7.0
# 5.0
# 1.0
# 3.0
# 4.0
# 10.0
# 9.0
# 7.0
# 9.0
# ...

# %%
X.shape
# Out:
#   (0, 0)	-1.0
#   (0, 1)	-1.0
#   (0, 2)	-1.0
#   (0, 3)	-0.999997
#   (0, 4)	-0.999729
#   (0, 5)	-0.989537
#   (0, 6)	-0.860165
#   (0, 7)	-0.395924
#   (0, 8)	0.048299
#   (0, 9)	-0.282151
#   (0, 10)	-0.816919
#   (0, 11)	-0.988564
#   (0, 12)	-0.999869
#   (0, 13)	-1.0
#   (0, 14)	-1.0
#   (0, 15)	-1.0
#   (0, 16)	-1.0
#   (0, 17)	-1.0
#   (0, 18)	-0.999999
#   (0, 19)	-0.999891
#   (0, 20)	-0.996208
#   (0, 21)	-0.94284
#   (0, 22)	-0.612719
#   (0, 23)	0.130807
#   (0, 24)	0.512043
#   :	:
#   (0, 231)	0.902149
#   (0, 232)	0.919526
#   (0, 233)	0.819451
#   (0, 234)	0.558884
#   (0, 235)	0.049978
#   (0, 236)	-0.565535
#   (0, 237)	-0.912456
#   (0, 238)	-0.993863
#   (0, 239)	-0.999857
#   (0, 240)	-0.99984
#   (0, 241)	-0.995876
#   (0, 242)	-0.957685
#   (0, 243)	-0.814635
#   (0, 244)	-0.547725
#   (0, 245)	-0.214728
#   (0, 246)	0.131298
#   (0, 247)	0.384728
#   (0, 248)	0.433073
#   (0, 249)	0.193397
#   (0, 250)	-0.237439
#   (0, 251)	-0.649848
#   (0, 252)	-0.906359
# ...

# %%
y.shape
# Out:
# (7291,)

# %%
data = load_svmlight_file('data/mnist_data.t')
X, y = data

# %%
temp = X.toarray()
# for i in range(784):
#     print(X[0, i])
img1 = temp[0, :].reshape(28, 28)
print(type(img1))
import matplotlib.pyplot as plt
plt.imshow(img1)
plt.show()
# Out:
# <class 'numpy.ndarray'>

# %%
y.shape
# Out:
# (10000,)

# %%
X.shape
# Out:
# (10000, 784)
